# %%
import pandas as pd
import numpy as np
from datetime import datetime
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# CHAMPIONS LEAGUE (UCL)

# %%
ucl_22_23 = pd.read_excel('data/CHAMPIONS 22-23.xlsx')
ucl_21_22 = pd.read_excel('data/CHAMPIONS 21-22.xlsx')
ucl_20_21 = pd.read_excel('data/CHAMPIONS 20-21.xlsx')
ucl_19_20 = pd.read_excel('data/CHAMPIONS 19-20.xlsx')
ucl_18_19 = pd.read_excel('data/CHAMPIONS 18-19.xlsx')
wc2018 = pd.read_excel('data/MUNDIAL 2018.xlsx')
ec2020 = pd.read_excel('data/EUROCUP 2020.xlsx')
wc2022 = pd.read_excel('data/MUNDIAL 2022.xlsx')

# %%
wc2018.drop(len(wc2018)-1, inplace= True)
wc2018['Type of match'] = 'Group Stage'
wc2018['Type of match'][0:32] = 'Play-Off'
wc2018['Type of match'][0:2] = 'Final'
wc2018['Competition'] = 'World Cup'
wc2018

wc2022.drop(len(wc2022)-1, inplace= True)
wc2022['Type of match'] = 'Group Stage'
wc2022['Type of match'][0:32] = 'Play-Off'
wc2022['Type of match'][0:2] = 'Final'
wc2022['Competition'] = 'World Cup'
wc2022

ec2020.drop(len(ec2020)-1, inplace=True)
ec2020['Type of match'] = 'Group Stage'
ec2020['Type of match'][0:30] = 'Play-Off'
ec2020['Type of match'][0:2] = 'Final'
ec2020['Competition'] = 'Euro Cup'
ec2020
# Out:
#     Match date                  Matches Unnamed: 2  InStat Index Goals  \
# 0   2021-07-11      Italy 1 : 1 England        ITA           275     1
# 1   2021-07-11      Italy 1 : 1 England        ENG           263     1
# 2   2021-07-07    England 2 : 1 Denmark        ENG           274     2
# 3   2021-07-07    England 2 : 1 Denmark        DEN           246     1
# 4   2021-07-06        Italy 1 : 1 Spain        ITA           267     1
# ..         ...                      ...        ...           ...   ...
# 97  2021-06-12     Belgium 3 : 0 Russia        RUS           220     -
# 98  2021-06-12  Wales 1 : 1 Switzerland        WAL           234     1
# 99  2021-06-12  Wales 1 : 1 Switzerland        SWI           245     1
# 100 2021-06-11       Turkey 0 : 3 Italy        TUR           225     -
# 101 2021-06-11       Turkey 0 : 3 Italy        ITA           285     3
#
#      Chances Chances successful Chances, % of conversion  Fouls Yellow cards  \
# 0          6                  1                      17%     21            5
# 1          1                  1                     100%     14            1
# 2          9                  2                      22%     10            1
# 3          3                  1                      33%     21            1
# 4          5                  1                      20%     17            2
# ..       ...                ...                      ...    ...          ...
# 97         2                  -                        -     11            -
# 98         3                  1                      33%      6            1
# 99         6                  1                      17%      9            2
# 100        2                  -                        -     10            2
# 101        9                  3                      33%      8            -
#
#      ... Pressing efficiency, % Ball possession, %  \
# 0    ...                    45%                62%
# 1    ...                    35%                38%
# 2    ...                    50%                59%
# 3    ...                    58%                41%
# 4    ...                    50%                31%
# ..   ...                    ...                ...
# 97   ...                    46%                38%
# 98   ...                    28%                37%
# 99   ...                    54%                63%
# 100  ...                    39%                37%
# 101  ...                    50%                63%
#
#     Entrances to the opposition half Entrances to the final third  \
# 0                                 77                           49
# 1                                 63                           40
# 2                                 70                           55
# 3                                 55                           30
# 4                                 48                           26
# ..                               ...                          ...
# 97                                50                           30
# 98                                42                           27
# 99                                61                           40
# 100                               27                           16
# 101                               81                           55
#
#      Entrance to the penalty box Average duration of ball possession, min  \
# 0                             13                                    23.93
# 1                             16                                    12.75
# 2                             28                                    21.70
# 3                              6                                    16.33
# 4                              7                                    11.18
# ..                           ...                                      ...
# 97                             8                                    13.97
# 98                            10                                    15.10
# 99                            20                                    22.94
# 100                            9                                    13.76
# 101                           19                                    20.39
#
#      Ball possessions, quantity Ball possession, sec  Type of match  \
# 0                           112              2680.61          Final
# 1                           128              1631.54          Final
# 2                           119              2582.48       Play-Off
# 3                           109              1780.51       Play-Off
# 4                           123              1374.90       Play-Off
# ..                          ...                  ...            ...
# 97                           94              1312.73    Group Stage
# 98                           78              1177.74    Group Stage
# 99                           89              2041.69    Group Stage
# 100                          89              1224.84    Group Stage
# 101                         104              2120.37    Group Stage
#
#     Competition
# 0      Euro Cup
# 1      Euro Cup
# 2      Euro Cup
# 3      Euro Cup
# 4      Euro Cup
# ..          ...
# 97     Euro Cup
# 98     Euro Cup
# 99     Euro Cup
# 100    Euro Cup
# 101    Euro Cup
#
# [102 rows x 37 columns]

# %%
ucl_22_23 = ucl_22_23.iloc[0:192]
ucl_22_23['Type of match'] = 'Group Stage'
ucl_22_23['Competition'] = 'Champions League'

ucl_21_22 = ucl_21_22.iloc[0:250]
ucl_21_22['Type of match'] = 'Group Stage'
ucl_21_22['Type of match'][0:58] = 'Play-Off'
ucl_21_22['Type of match'][0:2] = 'Final'
ucl_21_22['Competitions'] = 'Champions League'
ucl_21_22


ucl_20_21 = ucl_20_21.iloc[0:250]
ucl_20_21['Type of match'] = 'Group Stage'
ucl_20_21['Type of match'][0:58] = 'Play-Off'
ucl_20_21['Type of match'][0:2] = 'Final'
ucl_20_21['Competitions'] = 'Champions League'
ucl_20_21

ucl_19_20 = ucl_19_20.iloc[0:238]
ucl_19_20['Type of match'] = 'Group Stage'
ucl_19_20['Type of match'][0:46] = 'Play-Off'
ucl_19_20['Type of match'][0:2] = 'Final'
ucl_19_20['Competitions'] = 'Champions League'
ucl_19_20


ucl_18_19 = ucl_18_19.iloc[0:250]
ucl_18_19['Type of match'] = 'Group Stage'
ucl_18_19['Type of match'][0:58] = 'Play-Off'
ucl_18_19['Type of match'][0:2] = 'Final'
ucl_18_19['Competitions'] = 'Champions League'
ucl_18_19[50:65]
# Out:
#    Match date                    Matches Unnamed: 2 InStat Index Goals  \
# 50 2019-02-13   Tottenham 3 : 0 Dortmund        TOT          271     3
# 51 2019-02-13   Tottenham 3 : 0 Dortmund        DOR          225     -
# 52 2019-02-13     Ajax 1 : 2 Real Madrid        AJA          252     1
# 53 2019-02-13     Ajax 1 : 2 Real Madrid         RM          245     2
# 54 2019-02-12       Man United 0 : 2 PSG         MU          237     -
# 55 2019-02-12       Man United 0 : 2 PSG        PSG          275     2
# 56 2019-02-12           Roma 2 : 1 Porto        ROM          255     2
# 57 2019-02-12           Roma 2 : 1 Porto        POR          229     1
# 58 2018-12-12          Ajax 3 : 3 Bayern        AJA          249     3
# 59 2018-12-12          Ajax 3 : 3 Bayern        BAY          247     3
# 60 2018-12-12          Benfica 1 : 0 AEK        BEN          250     1
# 61 2018-12-12          Benfica 1 : 0 AEK        AEK          210     -
# 62 2018-12-12     Shakhtar D. 1 : 1 Lyon         SD          233     1
# 63 2018-12-12     Shakhtar D. 1 : 1 Lyon        LYO          245     1
# 64 2018-12-12  Man City 2 : 1 Hoffenheim         MC          275     2
#
#    Chances Chances successful Chances, % of conversion Fouls Yellow cards  \
# 50       6                  3                      50%    12            1
# 51       2                  -                        -     5            1
# 52      11                  1                       9%    10            1
# 53       4                  2                      50%    11            3
# 54       -                  -                        -    17            4
# 55       5                  2                      40%     7            4
# 56       5                  2                      40%    11            1
# 57       3                  1                      33%    12            1
# 58       8                  3                      38%    14            3
# 59       7                  3                      43%    15            2
# 60       7                  1                      14%     9            1
# 61       3                  -                        -    14            1
# 62       3                  1                      33%     7            1
# 63       4                  1                      25%    12            2
# 64      14                  2                      14%    11            -
#
#     ... Pressing efficiency, % Ball possession, %  \
# 50  ...                      -                56%
# 51  ...                      -                44%
# 52  ...                    50%                52%
# 53  ...                   100%                48%
# 54  ...                    25%                44%
# 55  ...                      -                56%
# 56  ...                      -                41%
# 57  ...                    33%                59%
# 58  ...                    56%                55%
# 59  ...                   100%                45%
# 60  ...                      -                60%
# 61  ...                      -                40%
# 62  ...                      -                51%
# 63  ...                    57%                49%
# 64  ...                    57%                61%
#
#    Entrances to the opposition half Entrances to the final third  \
# 50                               66                           41
# 51                               54                           27
# 52                               87                           60
# 53                               46                           22
# 54                               60                           41
# 55                               53                           27
# 56                               71                           41
# 57                               58                           32
# 58                               81                           49
# 59                               47                           30
# 60                               97                           67
# 61                               36                           23
# 62                               59                           36
# 63                               67                           46
# 64                               77                           63
#
#    Entrance to the penalty box Average duration of ball possession, min  \
# 50                          11                                    21.28
# 51                          10                                    15.04
# 52                          23                                     14.9
# 53                          10                                    13.74
# 54                          17                                    13.85
# 55                          11                                     17.5
# 56                          17                                    11.07
# 57                           8                                    16.97
# 58                          21                                    16.76
# 59                          17                                    13.25
# 60                          19                                    15.69
# 61                           8                                    11.71
# 62                          10                                     16.2
# 63                          21                                    16.74
# 64                          30                                    18.18
#
#    Ball possessions, quantity Ball possession, sec Type of match  \
# 50                        101                 2149      Play-Off
# 51                        111                 1669      Play-Off
# 52                        124                 1847      Play-Off
# 53                        124                 1704      Play-Off
# 54                        105                 1454      Play-Off
# 55                        104                 1820      Play-Off
# 56                        128                 1417      Play-Off
# 57                        118                 2003      Play-Off
# 58                        114              1910.86   Group Stage
# 59                        116              1536.75   Group Stage
# 60                        126                 1977   Group Stage
# 61                        112                 1312   Group Stage
# 62                        108                 1750   Group Stage
# 63                        101                 1691   Group Stage
# 64                        112                 2036   Group Stage
#
#         Competitions
# 50  Champions League
# 51  Champions League
# 52  Champions League
# 53  Champions League
# 54  Champions League
# 55  Champions League
# 56  Champions League
# 57  Champions League
# 58  Champions League
# 59  Champions League
# 60  Champions League
# 61  Champions League
# 62  Champions League
# 63  Champions League
# 64  Champions League
#
# [15 rows x 37 columns]

# %%
ucl= pd.concat([ucl_22_23, ucl_21_22, ucl_20_21, ucl_19_20, ucl_18_19, wc2018, ec2020, wc2022], axis= 0, ignore_index=True)
ucl
# Out:
#      Match date                       Matches Unnamed: 2 InStat Index Goals  \
# 0    2022-11-02      Real Madrid 5 : 1 Celtic         RM          266     5
# 1    2022-11-02      Real Madrid 5 : 1 Celtic        CEL          225     1
# 2    2022-11-02  Shakhtar D. 0 : 4 RB Leipzig         SD          209     -
# 3    2022-11-02  Shakhtar D. 0 : 4 RB Leipzig         RL          257     4
# 4    2022-11-02   Chelsea 2 : 1 Dinamo Zagreb        CHE          255     2
# ...         ...                           ...        ...          ...   ...
# 1533 2022-11-21     United States 1 : 1 Wales        WAL          234     1
# 1534 2022-11-21     Senegal 0 : 2 Netherlands        SEN          225     -
# 1535 2022-11-21     Senegal 0 : 2 Netherlands        NET          264     2
# 1536 2022-11-20           Qatar 0 : 2 Ecuador        QAT          212     -
# 1537 2022-11-20           Qatar 0 : 2 Ecuador        ECU          252     2
#
#      Chances Chances successful Chances, % of conversion Fouls Yellow cards  \
# 0         14                  5                      36%     6            -
# 1          5                  1                      20%     8            2
# 2          4                  -                        -    15            3
# 3          6                  4                      67%    10            -
# 4         12                  2                      17%    17            1
# ...      ...                ...                      ...   ...          ...
# 1533       4                  1                      25%    10            2
# 1534       5                  -                        -    13            2
# 1535       6                  2                      33%    14            1
# 1536       1                  -                        -    15            4
# 1537       5                  2                      40%    15            2
#
#       ... Ball possession, % Entrances to the opposition half  \
# 0     ...                62%                               57
# 1     ...                38%                               52
# 2     ...                51%                               39
# 3     ...                49%                               48
# 4     ...                59%                               80
# ...   ...                ...                              ...
# 1533  ...                41%                               47
# 1534  ...                50%                               50
# 1535  ...                50%                               64
# 1536  ...                48%                               37
# 1537  ...                52%                               59
#
#      Entrances to the final third Entrance to the penalty box  \
# 0                              44                          27
# 1                              39                          11
# 2                              21                           6
# 3                              31                          13
# 4                              53                          27
# ...                           ...                         ...
# 1533                           28                          16
# 1534                           37                          16
# 1535                           42                          15
# 1536                           14                           3
# 1537                           35                          16
#
#      Average duration of ball possession, min Ball possessions, quantity  \
# 0                                       26.15                         83
# 1                                       15.66                         84
# 2                                       20.83                         81
# 3                                       21.08                         76
# 4                                       18.16                        103
# ...                                       ...                        ...
# 1533                                    16.32                         94
# 1534                                    16.33                         99
# 1535                                    17.04                         96
# 1536                                    17.32                         83
# 1537                                    18.59                         85
#
#      Ball possession, sec Type of match       Competition Competitions
# 0                 2170.69   Group Stage  Champions League          NaN
# 1                 1315.64   Group Stage  Champions League          NaN
# 2                 1687.54   Group Stage  Champions League          NaN
# 3                  1601.7   Group Stage  Champions League          NaN
# 4                  1870.9   Group Stage  Champions League          NaN
# ...                   ...           ...               ...          ...
# 1533              1534.12   Group Stage         World Cup          NaN
# 1534              1616.62   Group Stage         World Cup          NaN
# 1535              1635.57   Group Stage         World Cup          NaN
# 1536              1437.83   Group Stage         World Cup          NaN
# 1537              1580.06   Group Stage         World Cup          NaN
#
# [1538 rows x 38 columns]

# %%
ucl.replace("-", 0, inplace=True)
ucl.rename(columns={'Unnamed: 2': 'Teams'}, inplace= True)
ucl.head()
# Out:
#   Match date                       Matches Teams  InStat Index  Goals  \
# 0 2022-11-02      Real Madrid 5 : 1 Celtic    RM           266      5
# 1 2022-11-02      Real Madrid 5 : 1 Celtic   CEL           225      1
# 2 2022-11-02  Shakhtar D. 0 : 4 RB Leipzig    SD           209      0
# 3 2022-11-02  Shakhtar D. 0 : 4 RB Leipzig    RL           257      4
# 4 2022-11-02   Chelsea 2 : 1 Dinamo Zagreb   CHE           255      2
#
#    Chances  Chances successful Chances, % of conversion  Fouls  Yellow cards  \
# 0       14                   5                      36%      6             0
# 1        5                   1                      20%      8             2
# 2        4                   0                        0     15             3
# 3        6                   4                      67%     10             0
# 4       12                   2                      17%     17             1
#
#    ...  Ball possession, % Entrances to the opposition half  \
# 0  ...                 62%                               57
# 1  ...                 38%                               52
# 2  ...                 51%                               39
# 3  ...                 49%                               48
# 4  ...                 59%                               80
#
#    Entrances to the final third  Entrance to the penalty box  \
# 0                            44                           27
# 1                            39                           11
# 2                            21                            6
# 3                            31                           13
# 4                            53                           27
#
#    Average duration of ball possession, min  Ball possessions, quantity  \
# 0                                     26.15                          83
# 1                                     15.66                          84
# 2                                     20.83                          81
# 3                                     21.08                          76
# 4                                     18.16                         103
#
#    Ball possession, sec Type of match       Competition  Competitions
# 0               2170.69   Group Stage  Champions League           NaN
# 1               1315.64   Group Stage  Champions League           NaN
# 2               1687.54   Group Stage  Champions League           NaN
# 3               1601.70   Group Stage  Champions League           NaN
# 4               1870.90   Group Stage  Champions League           NaN
#
# [5 rows x 38 columns]

# %%
ucl.drop(['InStat Index','Chances successful', 'Chances', 'Fouls', 'Red cards', 'Yellow cards', 'Tactics', 'Offsides', 'Corner',
            'Crosses', 'Accurate crosses, %',  'Ball recoveries in opponent\'s half', 'Ball recoveries', 'Lost balls'],
            inplace=True, axis=1)
ucl.columns
# Out:
# Index(['Match date', 'Matches', 'Teams', 'Goals', 'Chances, % of conversion',
#        'Shots', 'Shots on target', 'Passes', 'Accurate passes, %',
#        'Key passes', 'Key passes accurate', 'Lost balls in own half',
#        'Team pressing', 'Pressing efficiency, %', 'Ball possession, %',
#        'Entrances to the opposition half', 'Entrances to the final third',
#        'Entrance to the penalty box',
#        'Average duration of ball possession, min',
#        'Ball possessions, quantity', 'Ball possession, sec', 'Type of match',
#        'Competition', 'Competitions'],
#       dtype='object')

# %%
ucl['Ball possession, %'] = ucl['Ball possession, %'].str.rstrip('%').astype('float')
ucl['Chances, % of conversion'] = ucl['Chances, % of conversion'].str.rstrip('%').astype('float')
ucl['Accurate passes, %'] = ucl['Accurate passes, %'].str.rstrip('%').astype('float')
ucl['Pressing efficiency, %'] = ucl['Pressing efficiency, %'].str.rstrip('%').astype('float')

ucl.fillna(0, inplace=True)

ucl.head()
# Out:
#   Match date                       Matches Teams  Goals  \
# 0 2022-11-02      Real Madrid 5 : 1 Celtic    RM      5
# 1 2022-11-02      Real Madrid 5 : 1 Celtic   CEL      1
# 2 2022-11-02  Shakhtar D. 0 : 4 RB Leipzig    SD      0
# 3 2022-11-02  Shakhtar D. 0 : 4 RB Leipzig    RL      4
# 4 2022-11-02   Chelsea 2 : 1 Dinamo Zagreb   CHE      2
#
#    Chances, % of conversion  Shots  Shots on target  Passes  \
# 0                      36.0     23               11     780
# 1                      20.0     14                8     428
# 2                       0.0      5                1     502
# 3                      67.0     12                7     544
# 4                      17.0     19                6     648
#
#    Accurate passes, %  Key passes  ...  Ball possession, %  \
# 0                91.0          21  ...                62.0
# 1                86.0           6  ...                38.0
# 2                88.0           6  ...                51.0
# 3                89.0           8  ...                49.0
# 4                90.0          11  ...                59.0
#
#    Entrances to the opposition half  Entrances to the final third  \
# 0                                57                            44
# 1                                52                            39
# 2                                39                            21
# 3                                48                            31
# 4                                80                            53
#
#    Entrance to the penalty box  Average duration of ball possession, min  \
# 0                           27                                     26.15
# 1                           11                                     15.66
# 2                            6                                     20.83
# 3                           13                                     21.08
# 4                           27                                     18.16
#
#    Ball possessions, quantity  Ball possession, sec  Type of match  \
# 0                          83               2170.69    Group Stage
# 1                          84               1315.64    Group Stage
# 2                          81               1687.54    Group Stage
# 3                          76               1601.70    Group Stage
# 4                         103               1870.90    Group Stage
#
#         Competition  Competitions
# 0  Champions League             0
# 1  Champions League             0
# 2  Champions League             0
# 3  Champions League             0
# 4  Champions League             0
#
# [5 rows x 24 columns]

# %%
ucl['Match date'] = ucl['Match date'].astype(str)
ucl.insert(0, 'Partidos', ucl['Matches'] + " " + ucl['Match date'])
ucl.head()
# Out:
#                                   Partidos  Match date  \
# 0      Real Madrid 5 : 1 Celtic 2022-11-02  2022-11-02
# 1      Real Madrid 5 : 1 Celtic 2022-11-02  2022-11-02
# 2  Shakhtar D. 0 : 4 RB Leipzig 2022-11-02  2022-11-02
# 3  Shakhtar D. 0 : 4 RB Leipzig 2022-11-02  2022-11-02
# 4   Chelsea 2 : 1 Dinamo Zagreb 2022-11-02  2022-11-02
#
#                         Matches Teams  Goals  Chances, % of conversion  Shots  \
# 0      Real Madrid 5 : 1 Celtic    RM      5                      36.0     23
# 1      Real Madrid 5 : 1 Celtic   CEL      1                      20.0     14
# 2  Shakhtar D. 0 : 4 RB Leipzig    SD      0                       0.0      5
# 3  Shakhtar D. 0 : 4 RB Leipzig    RL      4                      67.0     12
# 4   Chelsea 2 : 1 Dinamo Zagreb   CHE      2                      17.0     19
#
#    Shots on target  Passes  Accurate passes, %  ...  Ball possession, %  \
# 0               11     780                91.0  ...                62.0
# 1                8     428                86.0  ...                38.0
# 2                1     502                88.0  ...                51.0
# 3                7     544                89.0  ...                49.0
# 4                6     648                90.0  ...                59.0
#
#    Entrances to the opposition half  Entrances to the final third  \
# 0                                57                            44
# 1                                52                            39
# 2                                39                            21
# 3                                48                            31
# 4                                80                            53
#
#    Entrance to the penalty box  Average duration of ball possession, min  \
# 0                           27                                     26.15
# 1                           11                                     15.66
# 2                            6                                     20.83
# 3                           13                                     21.08
# 4                           27                                     18.16
#
#    Ball possessions, quantity  Ball possession, sec  Type of match  \
# 0                          83               2170.69    Group Stage
# 1                          84               1315.64    Group Stage
# 2                          81               1687.54    Group Stage
# 3                          76               1601.70    Group Stage
# 4                         103               1870.90    Group Stage
#
#         Competition  Competitions
# 0  Champions League             0
# 1  Champions League             0
# 2  Champions League             0
# 3  Champions League             0
# 4  Champions League             0
#
# [5 rows x 25 columns]

# %%
def wdl(x):
    if (x+2) % 2 == 0:                                  #Distinction between Home and Visitor depending on its index position
        if ucl['Goals'][x] > ucl['Goals'][x+1]:     #(Home = odd, Visitor = even)
            x = 'Victory'                               #More goals than the immediate next row --> Victory
            return x                                    #Less goals than the immediate next row --> Loss
        elif ucl['Goals'][x] < ucl['Goals'][x+1]:   #Same goals --> Draw
            x = 'Loss'
            return x
        else:
            x = 'Draw'
            return x
    if (x+2) % 2 != 0:                                  #Same but with the previous row
        if ucl['Goals'][x] > ucl['Goals'][x-1]:
            x = 'Victory'
            return x
        elif ucl['Goals'][x] < ucl['Goals'][x-1]:
            x = 'Loss'
            return x
        else:
            x = 'Draw'
            return x

ucl['resultados'] = range(0, len(ucl))              #Create row with the same values as the index to iterate
ucl['resultados'] = ucl['resultados'].apply(wdl)    #Method.apply() to use it in every value of the column
ucl.head(4)
# Out:
#                                   Partidos  Match date  \
# 0      Real Madrid 5 : 1 Celtic 2022-11-02  2022-11-02
# 1      Real Madrid 5 : 1 Celtic 2022-11-02  2022-11-02
# 2  Shakhtar D. 0 : 4 RB Leipzig 2022-11-02  2022-11-02
# 3  Shakhtar D. 0 : 4 RB Leipzig 2022-11-02  2022-11-02
#
#                         Matches Teams  Goals  Chances, % of conversion  Shots  \
# 0      Real Madrid 5 : 1 Celtic    RM      5                      36.0     23
# 1      Real Madrid 5 : 1 Celtic   CEL      1                      20.0     14
# 2  Shakhtar D. 0 : 4 RB Leipzig    SD      0                       0.0      5
# 3  Shakhtar D. 0 : 4 RB Leipzig    RL      4                      67.0     12
#
#    Shots on target  Passes  Accurate passes, %  ...  \
# 0               11     780                91.0  ...
# 1                8     428                86.0  ...
# 2                1     502                88.0  ...
# 3                7     544                89.0  ...
#
#    Entrances to the opposition half  Entrances to the final third  \
# 0                                57                            44
# 1                                52                            39
# 2                                39                            21
# 3                                48                            31
#
#    Entrance to the penalty box  Average duration of ball possession, min  \
# 0                           27                                     26.15
# 1                           11                                     15.66
# 2                            6                                     20.83
# 3                           13                                     21.08
#
#    Ball possessions, quantity  Ball possession, sec  Type of match  \
# 0                          83               2170.69    Group Stage
# 1                          84               1315.64    Group Stage
# 2                          81               1687.54    Group Stage
# 3                          76               1601.70    Group Stage
#
#         Competition  Competitions  resultados
# 0  Champions League             0     Victory
# 1  Champions League             0        Loss
# 2  Champions League             0        Loss
# 3  Champions League             0     Victory
#
# [4 rows x 26 columns]

# %%
ucl.groupby(['resultados'])[['Ball possession, %']].mean()
ucl['Ball possession, %'].sum()
# Out:
# 76904.0

# %%
ucl['posesioncomp'] = range(0, len(ucl))
def pos_ucl(x):
    if (x+2) % 2 == 0:       
        return ucl['Ball possession, %'][x] + ucl['Ball possession, %'][x+1]                               
    elif (x+2) % 1 == 0:
        return ucl['Ball possession, %'][x] + ucl['Ball possession, %'][x-1]
    else:
        return False
    
ucl['posesioncomp'] = ucl['posesioncomp'].apply(pos_ucl)
ucl[ucl['posesioncomp'] != 100]
# Out:
#                                     Partidos  Match date  \
# 894       Juventus 3 : 0 Bayer 04 2019-10-01  2019-10-01
# 895       Juventus 3 : 0 Bayer 04 2019-10-01  2019-10-01
# 1078             Napoli 1 : 1 PSG 2018-11-06  2018-11-06
# 1079             Napoli 1 : 1 PSG 2018-11-06  2018-11-06
# 1160  Young Boys 0 : 3 Man United 2018-09-19  2018-09-19
# 1161  Young Boys 0 : 3 Man United 2018-09-19  2018-09-19
# 1288      Costa Rica 0 : 1 Serbia 2018-06-17  2018-06-17
# 1289      Costa Rica 0 : 1 Serbia 2018-06-17  2018-06-17
#
#                           Matches Teams  Goals  Chances, % of conversion  \
# 894       Juventus 3 : 0 Bayer 04   JUV      3                      50.0
# 895       Juventus 3 : 0 Bayer 04    B0      0                       0.0
# 1078             Napoli 1 : 1 PSG   NAP      1                      13.0
# 1079             Napoli 1 : 1 PSG   PSG      1                      33.0
# 1160  Young Boys 0 : 3 Man United    YB      0                       0.0
# 1161  Young Boys 0 : 3 Man United    MU      3                      43.0
# 1288      Costa Rica 0 : 1 Serbia    CR      0                       0.0
# 1289      Costa Rica 0 : 1 Serbia   SER      1                      17.0
#
#       Shots  Shots on target  Passes  Accurate passes, %  ...  \
# 894      10                6     541                87.0  ...
# 895       8                0     648                89.0  ...
# 1078     18                6     526                87.0  ...
# 1079      9                3     650                90.0  ...
# 1160     16                4     422                83.0  ...
# 1161     14                4     544                88.0  ...
# 1288     10                3     487                86.0  ...
# 1289     10                4     455                83.0  ...
#
#       Entrances to the final third  Entrance to the penalty box  \
# 894                             30                           13
# 895                             32                           12
# 1078                            39                           15
# 1079                            36                           19
# 1160                            49                           16
# 1161                            45                           18
# 1288                            39                           10
# 1289                            36                           18
#
#       Average duration of ball possession, min  Ball possessions, quantity  \
# 894                                      16.11                          99
# 895                                      18.34                         100
# 1078                                     18.50                         101
# 1079                                     24.08                          93
# 1160                                     14.71                         110
# 1161                                     17.03                         105
# 1288                                     16.01                         105
# 1289                                     15.88                         108
#
#       Ball possession, sec  Type of match  Competition      Competitions  \
# 894                1594.45    Group Stage            0  Champions League
# 895                1834.17    Group Stage            0  Champions League
# 1078               1869.00    Group Stage            0  Champions League
# 1079               2239.00    Group Stage            0  Champions League
# 1160               1618.00    Group Stage            0  Champions League
# 1161               1788.00    Group Stage            0  Champions League
# 1288               1681.00    Group Stage    World Cup                 0
# 1289               1715.00    Group Stage    World Cup                 0
#
#       resultados  posesioncomp
# 894      Victory         101.0
# 895         Loss         101.0
# 1078        Draw         101.0
# 1079        Draw         101.0
# 1160        Loss         101.0
# 1161     Victory         101.0
# 1288        Loss         101.0
# 1289     Victory         101.0
#
# [8 rows x 27 columns]

# %%
ucl.drop('posesioncomp', axis=1, inplace=True)
